# %%
import pandas as pd

air_quality_file1 = "./data/PRSA_Data_Aotizhongxin_20130301-20170228.csv"
air_quality_file2 = "./data/PRSA_Data_Changping_20130301-20170228.csv"
aotizhongxin_df = pd.read_csv(air_quality_file1, header=0)
changping_df = pd.read_csv(air_quality_file2, header=0)

aotizhongxin_df.set_index('No')
# Out:
#        year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# No
# 1      2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 2      2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 3      2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 4      2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 5      2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
# ...     ...    ...  ...   ...    ...   ...   ...   ...    ...   ...   ...
# 35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0  12.5
# 35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0  11.6
# 35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0  10.8
# 35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0  10.5
# 35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0   8.6
#
#          PRES  DEWP  RAIN   wd  WSPM       station
# No
# ...

# %%
aotizhongxin_df.drop_duplicates()
print(aotizhongxin_df.shape)
# Out:
# (35064, 18)

# %%
aotizhongxin_df = aotizhongxin_df.dropna()
print(aotizhongxin_df.shape)
# Out:
# (31815, 18)

# %%
def c_to_f(value):
  f = 9/5 * value + 32
  return f  

aotizhongxin_df['temp_f'] = aotizhongxin_df['TEMP'].map(c_to_f)

# %%
aotizhongxin_df['measurement_date'] = pd.to_datetime(aotizhongxin_df[['year', 'month', 'day', 'hour']])

drop_cols = ['year', 'month', 'day', 'hour']
aotizhongxin_df.drop(drop_cols, inplace=True, axis=1)

# %%
def decode_wd(value:str):
    WD_MAP = {
        'N': 'North', 
        'NNE': 'North Northeast', 
        'NE': 'Northeast',
        'ENE': 'West', 
        'E': 'East',
        'ESE': 'East Southeast',
        'SE': 'Southeast',
        'SSE': 'South Southeast',
        'S': 'South',
        'SSW': 'South Southwest',
        'SW': 'Southwest',
        'WSW': 'West Southwest',
        'W': 'West',
        'WNW': 'West Northwest',
        'NW': 'Northwest',
        'NNW': 'North Northwest',

    }
    if value in WD_MAP:
        return WD_MAP[value]
    else:
      return value

aotizhongxin_df['wd'] = aotizhongxin_df.wd.map(decode_wd)
